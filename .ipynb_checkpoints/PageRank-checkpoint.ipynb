# %% [markdown]
# # Page Rank
#
# A vida é muito bonita, gostaria de viver para sempre.
#
# - Eduardo Adame
# - Rodrigo Pintucci

# %%
import numpy as np
import numpy.linalg as la
import pandas as pd
import requests
import re
from urllib.parse import urlparse, urldefrag
from bs4 import BeautifulSoup as bs

# %% [markdown]
# ### Criando variáveis importantes.

# %%
all_links = set()

# %% [markdown]
# ### Definindo funções.

# %%
def find_probs(url: str):
    ################
    ### SCRAPING ###
    ################
    
    # Requisitando a página.
    raw_page = requests.get(url)
    
    # Adquirindo seu HTML.
    html_page = raw_page.text
    
    # Criando o objeto scrapper.
    soup = bs(html_page, 'lxml')
    
    # Capturando todos os links que levam à própria Wikipédia.
    links = soup.findAll('a', attrs= {'rel': 'mw:WikiLink'})
    
    # Criando lista de tuplas com links.
    data = [link.get('href') for link in links]
    
    # Criando dataframe a partir desses dados.
    df = pd.DataFrame(data, columns = ['link'])
    
    #####################
    ### PROBABILIDADE ###
    #####################
    
    # Retirando fragmento da url
    df['link'] = df['link'].apply(lambda x: urldefrag(x)[0])
    
    # Contabilizando quantas referências a cada link o site possui. 
    df = df.groupby(['link']).size().reset_index(name='count')
    
    # Criando a identificação da coluna a partir da url (padronizar).
    title = url.replace('https://pt.wikipedia.org/api/rest_v1/page/html', '.')
    
    # Criando essa coluna de probabilidades identificada pelo site.
    df[title] = df['count']/df['count'].sum()
    
    return df[['link', title]]

# %%
def scraping_loop(first_url: str):
    ##################################
    ### LOOP PRINCIPAL DE SCRAPING ###
    ##################################
    
    # Referenciando ao set que contém todos os links
    global all_links
    
    # Adicionando o link principal a esse set
    all_links.add(first_url)
    
    # Encontra os links (e suas probabilidades) para a url inicial
    links = find_probs(first_url)
    
    # Cria uma cópia para ser retornada após merge
    main_frame = links.copy()
    
    # Itera entre os links da url principal
    for link in links['link']:
        
        # Transformando a url relativa para a absoluta (e removendo o #titulo).
        full_link = link.replace('./', 'https://pt.wikipedia.org/api/rest_v1/page/html/')
        full_link = urldefrag(full_link)[0]
        
        # Checa se o link já foi utilizado
        if full_link in all_links:
            continue
        else:
            # Adiciona ao set de links o link
            all_links.add(full_link)
            
            # Cria a coluna de probabilidades para esse link
            probs = find_probs(full_link)
            
            # Faz um outer join com o main_frame
            main_frame = pd.merge(main_frame, probs, how='outer', on='link')
            
    return main_frame.fillna(0)

# %% [markdown]
# ### Gerando dataset.

# %%
url = 'https://pt.wikipedia.org/api/rest_v1/page/html/Álgebra_linear'

# %%
df2 = scraping_loop(url)

# %%
df2
# Out:
#                                 link  ./Álgebra_linear  \
# 0     ./Ajuda:Controle_de_autoridade          0.005319
# 1                ./Anel_(matemática)          0.005319
# 2                 ./Análise_complexa          0.005319
# 3                ./Análise_funcional          0.010638
# 4               ./Análise_matemática          0.005319
# ...                              ...               ...
# 7057               ./William_Lawvere          0.000000
# 7058              ./Álgebra_de_grafo          0.000000
# 7059             ./Álgebra_de_termos          0.000000
# 7060               ./Álgebra_simples          0.000000
# 7061                   ./Øystein_Ore          0.000000
#
#       ./Ajuda:Controle_de_autoridade  ./Anel_(matemática)  ./Análise_complexa  \
# 0                           0.033333             0.006369            0.007576
# 1                           0.000000             0.019108            0.000000
# 2                           0.000000             0.000000            0.045455
# 3                           0.000000             0.000000            0.007576
# 4                           0.000000             0.000000            0.015152
# ...                              ...                  ...                 ...
# 7057                        0.000000             0.000000            0.000000
# 7058                        0.000000             0.000000            0.000000
# 7059                        0.000000             0.000000            0.000000
# 7060                        0.000000             0.000000            0.000000
# 7061                        0.000000             0.000000            0.000000
#
#       ./Análise_funcional  ./Análise_matemática  ./Análise_matricial  \
# 0                0.004926              0.003774                  0.0
# 1                0.000000              0.000000                  0.0
# 2                0.009852              0.018868                  0.0
# 3                0.014778              0.018868                  0.0
# 4                0.019704              0.011321                  0.0
# ...                   ...                   ...                  ...
# 7057             0.000000              0.000000                  0.0
# 7058             0.000000              0.000000                  0.0
# 7059             0.000000              0.000000                  0.0
# 7060             0.000000              0.000000                  0.0
# 7061             0.000000              0.000000                  0.0
#
#       ./Análise_numérica  ./Análise_não_padronizada  ...    ./Zero  ./Álgebra  \
# 0               0.004831                   0.000000  ...  0.008403   0.005848
# 1               0.000000                   0.000000  ...  0.000000   0.011696
# 2               0.004831                   0.000000  ...  0.000000   0.005848
# 3               0.009662                   0.000000  ...  0.000000   0.005848
# 4               0.009662                   0.012658  ...  0.000000   0.011696
# ...                  ...                        ...  ...       ...        ...
# 7057            0.000000                   0.000000  ...  0.000000   0.000000
# 7058            0.000000                   0.000000  ...  0.000000   0.000000
# 7059            0.000000                   0.000000  ...  0.000000   0.000000
# 7060            0.000000                   0.000000  ...  0.000000   0.000000
# 7061            0.000000                   0.000000  ...  0.000000   0.000000
#
#       ./Álgebra_abstrata  ./Álgebra_booleana  ./Álgebra_comutativa  \
# 0               0.000000            0.000000              0.000000
# 1               0.010929            0.012195              0.022222
# 2               0.005464            0.000000              0.022222
# 3               0.005464            0.000000              0.000000
# 4               0.005464            0.000000              0.000000
# ...                  ...                 ...                   ...
# 7057            0.000000            0.000000              0.000000
# 7058            0.000000            0.000000              0.000000
# 7059            0.000000            0.000000              0.000000
# 7060            0.000000            0.000000              0.000000
# 7061            0.000000            0.000000              0.000000
#
#       ./Álgebra_elementar  ./Álgebra_linear_numérica  ./Álgebra_multilinear  \
# 0                0.000000                        0.0               0.000000
# 1                0.008333                        0.0               0.000000
# 2                0.008333                        0.0               0.013699
# 3                0.008333                        0.0               0.013699
# 4                0.008333                        0.0               0.013699
# ...                   ...                        ...                    ...
# 7057             0.000000                        0.0               0.000000
# 7058             0.000000                        0.0               0.000000
# 7059             0.000000                        0.0               0.000000
# 7060             0.000000                        0.0               0.000000
# 7061             0.000000                        0.0               0.000000
#
#       ./Álgebra_não_linear  ./Álgebra_universal
# 0                      0.0             0.000000
# 1                      0.0             0.024793
# 2                      0.0             0.000000
# 3                      0.0             0.000000
# 4                      0.0             0.000000
# ...                    ...                  ...
# 7057                   0.0             0.016529
# 7058                   0.0             0.008264
# 7059                   0.0             0.008264
# 7060                   0.0             0.008264
# 7061                   0.0             0.008264
#
# [7062 rows x 149 columns]

# %%
df2.drop(columns = ['link']).sum(axis=0).sum(axis=0)
# Out:
# 139.0

# %%
df2['link'].nunique()
# Out:
# 7062

# %%
df2.to_csv("my_wikipedia.csv", index=False)
